# %% [markdown]
# ## (2) Data Structures (objects)

# %% [markdown]
# >* Python is object oriented programming language, so every thing is object ( has properties + behaviors)
# * Objects have a __type__ that defines the kinds of things programs can do to them
# * Objects are
#     * scalar (cannot be subdivided)
#     * non-scalar (have internal structure that can be accessed)

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# ### SCALAR OBJECTS

# %% [markdown]
# * __int__ :      represent integers, ex. 5
# * __float__ :    represent real numbers, ex. 3.27
# * __bool__ :     represent Boolean values (True and False)
# * __NoneType__:  special and has one value, None
#
# You can use type() to see the type of an object
# > *Common data types include:*
# * int (for integer)
# * float
# * bool (for Boolean True/False)
# * str (for string)
# * list
# * tuple
# * dict (for dictionary)
# * set

# %%
type(100)
# Out:
# int

# %%
type(-10)
# Out:
# int

# %%
type(5.71215165)
# Out:
# float

# %%
type(5.0)
# Out:
# float

# %%
type(5)
# Out:
# int

# %%
type(10/2)
# Out:
# float

# %%
10/2
# Out:
# 5.0

# %%
5 == 5 # Check (TEST) ( Is 5 equals 5?)
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
8>4
# Out:
# True

# %%
type(5 == 5)
# Out:
# bool

# %%
v = None
print(type(v))
# Out:
# <class 'NoneType'>

# %%
x = print('Hello')
print(x)
# Out:
# Hello
# None

# %%
type(print('Hello'))
# Out:
# Hello
# NoneType

# %% [markdown]
# ### TYPE CONVERSIONS (CAST)

# %%
float(3)
# Out:
# 3.0

# %%
int(3.1)
# Out:
# 3

# %%
int(3.9)
# Out:
# 3

# %%
int(3/4)  # 0.75
# Out:
# 0

# %%
int('12541')
# Out:
# 12541

# %%
int('st-12541')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 int('st-12541')
#
# ValueError: invalid literal for int() with base 10: 'st-12541'

# %%
float('1.5')
# Out:
# 1.5

# %%
float('1.5m')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 float('1.5m')
#
# ValueError: could not convert string to float: '1.5m'

# %% [markdown]
# ### Boolean Logic

# %% [markdown]
# #### And Operation

# %%
input1 = (1 == 1)
input2 = (2 == 2)
input1 and input2
# Out:
# True

# %%
(1 == 1) and (2 == 2)
# Out:
# True

# %%
1 == 1 and 2 == 3
# Out:
# False

# %%
1 != 1 and 2 == 2
# Out:
# False

# %%
2 < 1 and 3 >  6
# Out:
# False

# %% [markdown]
#  #### Or Operation

# %%
1 == 1 or 2 == 2
# Out:
# True

# %%
1 == 1 or 2 == 3
# Out:
# True

# %%
1 != 1 or 2 == 2
# Out:
# True

# %%
2 < 1 or 3 >  6
# Out:
# False

# %% [markdown]
#  #### Not Operation

# %%
not 1 == 1
# Out:
# False

# %%
not 1 > 7
# Out:
# True
