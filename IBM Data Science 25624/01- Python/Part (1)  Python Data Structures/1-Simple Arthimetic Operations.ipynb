# %% [markdown]
# ## (0) Your First Program

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# ### Your Python Version

# %%
# Check the Python Version <<<< This is a comment
# Another Comment

import sys
print(sys.version)
# Out:
# 3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, 18:05:47) [MSC v.1916 64 bit (AMD64)]

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
# Check the Python Version
# !python --version    # As we are using Command Prompt
# Out:
# Python 3.11.7

# %%
'''
Multi line Comment
Check the Python Version <<<< This is a comment
Another Comment
New Line
'''

# %% [markdown]
# ## (1) Simple Arthimetic Operations

# %%
print(2 + 2)
# Out:
# 4

# %%
5 + 4 - 3
# Out:
# 6

# %%
(2 * 3) + 4
# Out:
# 10

# %%
10 / 2
# Out:
# 5.0

# %%
(-7 + 2) * (-4)
# Out:
# 20

# %%
-7 + 2 * -4
# Out:
# -15

# %%
-7 + (2 * -4)
# Out:
# -15

# %% [markdown]
# __Parentheses__ used to tell Python to do these operations first
# * Operator precedence without parentheses
#   * \**
#   * \*
#   * /
#   * \+ and – executed left to right

# %%
-7 + 2 * -4
# Out:
# -15

# %%
11 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 11 / 0
#
# ZeroDivisionError: division by zero

# %%
# distance = input("Enter distance in km: ")
# time = input("Enter time in minutes: ")

# speed = distance / time
# print(speed)

# %%
# Exponentiation >> just a comment
2**5
# Out:
# 32

# %%
9 ** (1/2)
# Out:
# 3.0

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
"""             <<<<< THIS IS A MULTILINE COMMENT
Quotient 
(Integer Division)
"""
20 // 6 # >>> 3
# Out:
# 3

# %%
# Remainder
20 % 6
# Out:
# 2

# %% [markdown]
# ### Numeric Built-in Functions

# %%
print(min(1, 2, 3, 4, 0, 2, 1))
print(max([1, 4, 9, 2, 5, 6, 8]))
print(abs(-99))
print(abs(42))
print(sum([1, 2, 3, 4, 5]))
# Out:
# 0
# 9
# 99
# 42
# 15

# %%
# What is the result of this code?
a=min([sum([11, 22]), max(abs(-30), 2)])
print(a)
# Out:
# 30
