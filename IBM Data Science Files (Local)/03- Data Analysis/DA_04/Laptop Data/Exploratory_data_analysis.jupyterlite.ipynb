# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on lab: Exploratory Data Analysis - Laptops Pricing dataset**

# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
#  - Visualize individual feature patterns
#  - Run descriptive statistical analysis on the dataset
#  - Use groups and pivot tables to find the effect of categorical variables on price
#  - Use Pearson Correlation to measure the interdependence between variables

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
filepath="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv"
# df = pd.read_csv(filepath, header=None)
# df = pd.read_csv(filepath, index_col=0)
df = pd.read_csv(filepath)
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)
# df = pd.read_csv('clean_df_of_Laptop_Pricing.csv')

# %% [markdown]
# Print the first 5 entries of the dataset to confirm loading.

# %%
df.head(5)
# Out:
#   Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_inch  CPU_frequency  \
# 0         Acer         4    2   1         5              14.0       0.551724
# 1         Dell         3    1   1         3              15.6       0.689655
# 2         Dell         3    1   1         7              15.6       0.931034
# 3         Dell         4    2   1         5              13.3       0.551724
# 4           HP         4    2   1         7              15.6       0.620690
#
#    RAM_GB  Storage_GB_SSD  Weight_pounds  Price Price-binned  Screen-Full_HD  \
# 0       8             256        3.52800    978          Low               0
# 1       4             256        4.85100    634          Low               1
# 2       8             256        4.85100    946          Low               1
# 3       8             128        2.69010   1244          Low               0
# 4       8             256        4.21155    837          Low               1
#
#    Screen-IPS_panel
# 0                 1
# 1                 0
# 2                 0
# 3                 1
# 4                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      238 non-null    object
#  1   Category          238 non-null    int64
#  2   GPU               238 non-null    int64
#  3   OS                238 non-null    int64
#  4   CPU_core          238 non-null    int64
#  5   Screen_Size_inch  238 non-null    float64
#  6   CPU_frequency     238 non-null    float64
#  7   RAM_GB            238 non-null    int64
#  8   Storage_GB_SSD    238 non-null    int64
#  9   Weight_pounds     238 non-null    float64
#  10  Price             238 non-null    int64
#  11  Price-binned      238 non-null    object
#  12  Screen-Full_HD    238 non-null    int64
#  13  Screen-IPS_panel  238 non-null    int64
# dtypes: float64(3), int64(9), object(2)
# memory usage: 26.2+ KB

# %%
df.describe()
# Out:
#          Category         GPU          OS    CPU_core  Screen_Size_inch  \
# count  238.000000  238.000000  238.000000  238.000000        238.000000
# mean     3.205882    2.151261    1.058824    5.630252         14.688655
# std      0.776533    0.638282    0.235790    1.241787          1.166045
# min      1.000000    1.000000    1.000000    3.000000         12.000000
# 25%      3.000000    2.000000    1.000000    5.000000         14.000000
# 50%      3.000000    2.000000    1.000000    5.000000         15.000000
# 75%      4.000000    3.000000    1.000000    7.000000         15.600000
# max      5.000000    3.000000    2.000000    7.000000         17.300000
#
#        CPU_frequency      RAM_GB  Storage_GB_SSD  Weight_pounds        Price  \
# count     238.000000  238.000000      238.000000     238.000000   238.000000
# mean        0.813822    7.882353      245.781513       4.106221  1462.344538
# std         0.141860    2.482603       34.765316       1.078442   574.607699
# min         0.413793    4.000000      128.000000       1.786050   527.000000
# 25%         0.689655    8.000000      256.000000       3.246863  1066.500000
# 50%         0.862069    8.000000      256.000000       4.106221  1333.000000
# 75%         0.931034    8.000000      256.000000       4.851000  1777.000000
# max         1.000000   16.000000      256.000000       7.938000  3810.000000
#
#        Screen-Full_HD  Screen-IPS_panel
# count      238.000000        238.000000
# mean         0.676471          0.323529
# std          0.468809          0.468809
# min          0.000000          0.000000
# 25%          0.000000          0.000000
# 50%          1.000000          0.000000
# 75%          1.000000          1.000000
# max          1.000000          1.000000

# %%
df.shape
# Out:
# (238, 14)

# %%
df.isnull().sum()
# Out:
# Manufacturer        0
# Category            0
# GPU                 0
# OS                  0
# CPU_core            0
# Screen_Size_inch    0
# CPU_frequency       0
# RAM_GB              0
# Storage_GB_SSD      0
# Weight_pounds       0
# Price               0
# Price-binned        0
# Screen-Full_HD      0
# Screen-IPS_panel    0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Manufacturer         object
# Category              int64
# GPU                   int64
# OS                    int64
# CPU_core              int64
# Screen_Size_inch    float64
# CPU_frequency       float64
# RAM_GB                int64
# Storage_GB_SSD        int64
# Weight_pounds       float64
# Price                 int64
# Price-binned         object
# Screen-Full_HD        int64
# Screen-IPS_panel      int64
# dtype: object

# %% [markdown]
# # Task 1 - Visualize individual feature patterns
#
# ### Continuous valued features
# Generate regression plots for each of the parameters "CPU_frequency", "Screen_Size_inch" and "Weight_pounds" against "Price". Also, print the value of correlation of each feature with "Price".

# %%
# Write your code below and press Shift+Enter to execute
# CPU_frequency plot
sns.regplot(x='CPU_frequency', y='Price', data=df)
# Out:
# <Axes: xlabel='CPU_frequency', ylabel='Price'>

# %%
# Write your code below and press Shift+Enter to execute
# Screen_Size_inch plot
sns.regplot(x='Screen_Size_inch', y='Price', data=df)
# Out:
# <Axes: xlabel='Screen_Size_inch', ylabel='Price'>

# %%
# Write your code below and press Shift+Enter to execute
# Weight_pounds plot
sns.regplot(x='Weight_pounds', y='Price', data=df)
# Out:
# <Axes: xlabel='Weight_pounds', ylabel='Price'>

# %%
# Correlation values of the three attributes with Price
cpu_corr = df['CPU_frequency'].corr(df['Price'])
print("Correlation between CPU_frequency and Price:", cpu_corr)
cpu_corr = df['Screen_Size_inch'].corr(df['Price'])
print("Correlation between Screen_Size_inch and Price:", cpu_corr)
cpu_corr = df['Weight_pounds'].corr(df['Price'])
print("Correlation between Weight_pounds and Price:", cpu_corr)
# Out:
# Correlation between CPU_frequency and Price: 0.3666655589258857
# Correlation between Screen_Size_inch and Price: -0.11064420817118281
# Correlation between Weight_pounds and Price: -0.05031225837751543

# %% [markdown]
# Interpretation: "CPU_frequency" has a 36% positive correlation with the price of the laptops. The other two parameters have weak correlation with price.

# %% [markdown]
# ### Categorical features
# Generate Box plots for the different feature that hold categorical values. These features would be "Category", "GPU", "OS", "CPU_core", "RAM_GB", "Storage_GB_SSD"

# %%
# Write your code below and press Shift+Enter to execute
# Category Box plot

sns.boxplot( y="Category", data=df)
# Out:
# <Axes: ylabel='Category'>

# %%
# Write your code below and press Shift+Enter to execute
# GPU Box plot
sns.boxplot( y="GPU", data=df)
# Out:
# <Axes: ylabel='GPU'>

# %%
# Write your code below and press Shift+Enter to execute
# OS Box plot

sns.boxplot( y="OS", data=df)
# Out:
# <Axes: ylabel='OS'>

# %%
# Write your code below and press Shift+Enter to execute
# CPU_core Box plot

sns.boxplot( y="CPU_core", data=df)
# Out:
# <Axes: ylabel='CPU_core'>

# %%
# Write your code below and press Shift+Enter to execute
# RAM_GB Box plot

sns.boxplot( y="RAM_GB", data=df)
# Out:
# <Axes: ylabel='RAM_GB'>

# %%
# Write your code below and press Shift+Enter to execute
# Storage_GB_SSD Box plot

sns.boxplot( y="Storage_GB_SSD", data=df)
# Out:
# <Axes: ylabel='Storage_GB_SSD'>

# %% [markdown]
# # Task 2 - Descriptive Statistical Analysis

# %% [markdown]
# Generate the statistical description of all the features being used in the data set. Include "object" data types as well.

# %%
df.describe()
# Out:
#          Category         GPU          OS    CPU_core  Screen_Size_inch  \
# count  238.000000  238.000000  238.000000  238.000000        238.000000
# mean     3.205882    2.151261    1.058824    5.630252         14.688655
# std      0.776533    0.638282    0.235790    1.241787          1.166045
# min      1.000000    1.000000    1.000000    3.000000         12.000000
# 25%      3.000000    2.000000    1.000000    5.000000         14.000000
# 50%      3.000000    2.000000    1.000000    5.000000         15.000000
# 75%      4.000000    3.000000    1.000000    7.000000         15.600000
# max      5.000000    3.000000    2.000000    7.000000         17.300000
#
#        CPU_frequency      RAM_GB  Storage_GB_SSD  Weight_pounds        Price  \
# count     238.000000  238.000000      238.000000     238.000000   238.000000
# mean        0.813822    7.882353      245.781513       4.106221  1462.344538
# std         0.141860    2.482603       34.765316       1.078442   574.607699
# min         0.413793    4.000000      128.000000       1.786050   527.000000
# 25%         0.689655    8.000000      256.000000       3.246863  1066.500000
# 50%         0.862069    8.000000      256.000000       4.106221  1333.000000
# 75%         0.931034    8.000000      256.000000       4.851000  1777.000000
# max         1.000000   16.000000      256.000000       7.938000  3810.000000
#
#        Screen-Full_HD  Screen-IPS_panel
# count      238.000000        238.000000
# mean         0.676471          0.323529
# std          0.468809          0.468809
# min          0.000000          0.000000
# 25%          0.000000          0.000000
# 50%          1.000000          0.000000
# 75%          1.000000          1.000000
# max          1.000000          1.000000

# %%
df.describe(include=['object'])
# Out:
#        Manufacturer Price-binned
# count           238          238
# unique           11            3
# top            Dell          Low
# freq             71          160

# %%
df.describe(include='all')
# Out:
#        Manufacturer    Category         GPU          OS    CPU_core  \
# count           238  238.000000  238.000000  238.000000  238.000000
# unique           11         NaN         NaN         NaN         NaN
# top            Dell         NaN         NaN         NaN         NaN
# freq             71         NaN         NaN         NaN         NaN
# mean            NaN    3.205882    2.151261    1.058824    5.630252
# std             NaN    0.776533    0.638282    0.235790    1.241787
# min             NaN    1.000000    1.000000    1.000000    3.000000
# 25%             NaN    3.000000    2.000000    1.000000    5.000000
# 50%             NaN    3.000000    2.000000    1.000000    5.000000
# 75%             NaN    4.000000    3.000000    1.000000    7.000000
# max             NaN    5.000000    3.000000    2.000000    7.000000
#
#         Screen_Size_inch  CPU_frequency      RAM_GB  Storage_GB_SSD  \
# count         238.000000     238.000000  238.000000      238.000000
# unique               NaN            NaN         NaN             NaN
# top                  NaN            NaN         NaN             NaN
# freq                 NaN            NaN         NaN             NaN
# mean           14.688655       0.813822    7.882353      245.781513
# std             1.166045       0.141860    2.482603       34.765316
# min            12.000000       0.413793    4.000000      128.000000
# 25%            14.000000       0.689655    8.000000      256.000000
# 50%            15.000000       0.862069    8.000000      256.000000
# 75%            15.600000       0.931034    8.000000      256.000000
# max            17.300000       1.000000   16.000000      256.000000
#
#         Weight_pounds        Price Price-binned  Screen-Full_HD  \
# count      238.000000   238.000000          238      238.000000
# unique            NaN          NaN            3             NaN
# top               NaN          NaN          Low             NaN
# freq              NaN          NaN          160             NaN
# mean         4.106221  1462.344538          NaN        0.676471
# std          1.078442   574.607699          NaN        0.468809
# min          1.786050   527.000000          NaN        0.000000
# 25%          3.246863  1066.500000          NaN        0.000000
# 50%          4.106221  1333.000000          NaN        1.000000
# 75%          4.851000  1777.000000          NaN        1.000000
# max          7.938000  3810.000000          NaN        1.000000
#
#         Screen-IPS_panel
# count         238.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean            0.323529
# std             0.468809
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             1.000000
# max             1.000000

# %%
df['Manufacturer'].value_counts().to_frame()
# Out:
#               count
# Manufacturer
# Dell             71
# Lenovo           52
# HP               49
# Acer             19
# Asus             18
# Toshiba          17
# Samsung           5
# MSI               4
# Huawei            1
# Razer             1
# Xiaomi            1

# %%
# Write your code below and press Shift+Enter to execute
df['Price-binned'].value_counts().to_frame()
# Out:
#               count
# Price-binned
# Low             160
# Medium           72
# High              6

# %% [markdown]
# # Task 3 - GroupBy and Pivot Tables
#
# Group the parameters "GPU", "CPU_core" and "Price" to make a pivot table and visualize this connection using the pcolor plot.

# %%
print(df['GPU'].unique())
print(df['CPU_core'].unique())
# print(df['Price'].unique())
# Out:
# [2 1 3]
# [5 3 7]

# %%
# Write your code below and press Shift+Enter to execute
# Create the group
df_group_one = df[['GPU', 'CPU_core', 'Price']]

df_group_one
# Out:
#      GPU  CPU_core  Price
# 0      2         5    978
# 1      1         3    634
# 2      1         7    946
# 3      2         5   1244
# 4      2         7    837
# ..   ...       ...    ...
# 233    2         7   1891
# 234    2         5   1950
# 235    2         5   2236
# 236    3         5    883
# 237    2         5   1499
#
# [238 rows x 3 columns]

# %%
# Write your code below and press Shift+Enter to execute
# Create the Pivot table
pivot_table = df.pivot_table(index='GPU', columns='CPU_core', values='Price')
pivot_table
# Out:
# CPU_core           3            5            7
# GPU
# 1         769.250000   998.500000  1167.941176
# 2         785.076923  1462.197674  1744.621622
# 3         784.000000  1220.680000  1945.097561

# %%
# Write your code below and press Shift+Enter to execute
# Create the Plot
plt.pcolor(pivot_table, cmap='RdBu')
plt.colorbar()
plt.xlabel('CPU Core')
plt.ylabel('GPU')
plt.title('Price by GPU and CPU Core')
plt.show()

# %% [markdown]
# # Task 4 - Pearson Correlation and p-values
#
# Use the `scipy.stats.pearsonr()` function to evaluate the Pearson Coefficient and the p-values for each parameter tested above. This will help you determine the parameters most likely to have a strong effect on the price of the laptops.

# %%
# Write your code below and press Shift+Enter to execute
df.corr(numeric_only=True)
# Out:
#                   Category       GPU        OS  CPU_core  Screen_Size_inch  \
# Category          1.000000 -0.114174 -0.043378  0.232425         -0.285392
# GPU              -0.114174  1.000000 -0.199549  0.145388          0.154251
# OS               -0.043378 -0.199549  1.000000  0.016954          0.146695
# CPU_core          0.232425  0.145388  0.016954  1.000000          0.041092
# Screen_Size_inch -0.285392  0.154251  0.146695  0.041092          1.000000
# CPU_frequency    -0.053414  0.291439  0.050407  0.242722         -0.000948
# RAM_GB            0.030127  0.218973 -0.074625  0.473075          0.018194
# Storage_GB_SSD    0.038246  0.094288  0.007751  0.400015          0.119699
# Weight_pounds    -0.381032  0.262853  0.120858  0.068599          0.797534
# Price             0.286243  0.288298 -0.221730  0.459398         -0.110644
# Screen-Full_HD   -0.117608 -0.089582  0.172891  0.003837          0.342912
# Screen-IPS_panel  0.117608  0.089582 -0.172891 -0.003837         -0.342912
#
#                   CPU_frequency    RAM_GB  Storage_GB_SSD  Weight_pounds  \
# Category              -0.053414  0.030127        0.038246      -0.381032
# GPU                    0.291439  0.218973        0.094288       0.262853
# OS                     0.050407 -0.074625        0.007751       0.120858
# CPU_core               0.242722  0.473075        0.400015       0.068599
# Screen_Size_inch      -0.000948  0.018194        0.119699       0.797534
# CPU_frequency          1.000000  0.226736        0.035557       0.066522
# RAM_GB                 0.226736  1.000000        0.361469       0.055068
# Storage_GB_SSD         0.035557  0.361469        1.000000       0.112519
# Weight_pounds          0.066522  0.055068        0.112519       1.000000
# Price                  0.366666  0.549297        0.243421      -0.050312
# Screen-Full_HD         0.055273  0.017913        0.061402       0.117909
# Screen-IPS_panel      -0.055273 -0.017913       -0.061402      -0.117909
#
#                      Price  Screen-Full_HD  Screen-IPS_panel
# Category          0.286243       -0.117608          0.117608
# GPU               0.288298       -0.089582          0.089582
# OS               -0.221730        0.172891         -0.172891
# CPU_core          0.459398        0.003837         -0.003837
# Screen_Size_inch -0.110644        0.342912         -0.342912
# CPU_frequency     0.366666        0.055273         -0.055273
# RAM_GB            0.549297        0.017913         -0.017913
# Storage_GB_SSD    0.243421        0.061402         -0.061402
# Weight_pounds    -0.050312        0.117909         -0.117909
# Price             1.000000       -0.021075          0.021075
# Screen-Full_HD   -0.021075        1.000000         -1.000000
# Screen-IPS_panel  0.021075       -1.000000          1.000000

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Category            0.286243
# GPU                 0.288298
# OS                 -0.221730
# CPU_core            0.459398
# Screen_Size_inch   -0.110644
# CPU_frequency       0.366666
# RAM_GB              0.549297
# Storage_GB_SSD      0.243421
# Weight_pounds      -0.050312
# Price               1.000000
# Screen-Full_HD     -0.021075
# Screen-IPS_panel    0.021075
# Name: Price, dtype: float64

# %%
df.corr(numeric_only=True)[['Price']].style.background_gradient(cmap='RdGy')
# Out:
# <style type="text/css">
# #T_7575f_row0_col0, #T_7575f_row1_col0 {
#   background-color: #fde1d0;
#   color: #000000;
# }
# #T_7575f_row2_col0 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_7575f_row3_col0 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_7575f_row4_col0 {
#   background-color: #ab162a;
#   color: #f1f1f1;
# }
# #T_7575f_row5_col0 {
#   background-color: #fff9f5;
#   color: #000000;
# }
# #T_7575f_row6_col0 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_7575f_row7_col0 {
#   background-color: #fbd0b9;
#   color: #000000;
# }
# #T_7575f_row8_col0 {
#   background-color: #bf3338;
#   color: #f1f1f1;
# }
# #T_7575f_row9_col0 {
#   background-color: #1a1a1a;
#   color: #f1f1f1;
# }
# #T_7575f_row10_col0 {
#   background-color: #c94741;
#   color: #f1f1f1;
# }
# #T_7575f_row11_col0 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7575f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7575f_level0_col0" class="col_heading level0 col0" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7575f_level0_row0" class="row_heading level0 row0" >Category</th>
#       <td id="T_7575f_row0_col0" class="data row0 col0" >0.286243</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row1" class="row_heading level0 row1" >GPU</th>
#       <td id="T_7575f_row1_col0" class="data row1 col0" >0.288298</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row2" class="row_heading level0 row2" >OS</th>
#       <td id="T_7575f_row2_col0" class="data row2 col0" >-0.221730</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row3" class="row_heading level0 row3" >CPU_core</th>
#       <td id="T_7575f_row3_col0" class="data row3 col0" >0.459398</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row4" class="row_heading level0 row4" >Screen_Size_inch</th>
#       <td id="T_7575f_row4_col0" class="data row4 col0" >-0.110644</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row5" class="row_heading level0 row5" >CPU_frequency</th>
#       <td id="T_7575f_row5_col0" class="data row5 col0" >0.366666</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row6" class="row_heading level0 row6" >RAM_GB</th>
#       <td id="T_7575f_row6_col0" class="data row6 col0" >0.549297</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row7" class="row_heading level0 row7" >Storage_GB_SSD</th>
#       <td id="T_7575f_row7_col0" class="data row7 col0" >0.243421</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row8" class="row_heading level0 row8" >Weight_pounds</th>
#       <td id="T_7575f_row8_col0" class="data row8 col0" >-0.050312</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row9" class="row_heading level0 row9" >Price</th>
#       <td id="T_7575f_row9_col0" class="data row9 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row10" class="row_heading level0 row10" >Screen-Full_HD</th>
#       <td id="T_7575f_row10_col0" class="data row10 col0" >-0.021075</td>
#     </tr>
#     <tr>
#       <th id="T_7575f_level0_row11" class="row_heading level0 row11" >Screen-IPS_panel</th>
#       <td id="T_7575f_row11_col0" class="data row11 col0" >0.021075</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.corr(numeric_only=True)['Price'].apply(abs).sort_values(ascending=False)
# Out:
# Price               1.000000
# RAM_GB              0.549297
# CPU_core            0.459398
# CPU_frequency       0.366666
# GPU                 0.288298
# Category            0.286243
# Storage_GB_SSD      0.243421
# OS                  0.221730
# Screen_Size_inch    0.110644
# Weight_pounds       0.050312
# Screen-Full_HD      0.021075
# Screen-IPS_panel    0.021075
# Name: Price, dtype: float64

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['RAM_GB'], df['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5492972971857841  with a P-value of P = 3.6815606288429613e-20

# %%
pearson_coef, p_value = stats.pearsonr(df['CPU_core'], df['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.45939777733551157  with a P-value of P = 7.912950127009034e-14

# %%
pearson_coef, p_value = stats.pearsonr(df['CPU_frequency'], df['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.36666555892588604  with a P-value of P = 5.5024633507134225e-09

# %%
sns.regplot(x='RAM_GB', y='Price', data=df)
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>
