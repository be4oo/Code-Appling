# %%
import pandas as pd

# %%
# path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
# df = pd.read_csv(path)
# df.head()

# %%
# df.to_csv('Car_Price.csv', index=False)

# %%
df = pd.read_csv('CarPrice_Assignment.csv')
df.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
'tree' in df.cylindernumber
# Out:
# False

# %% [markdown]
# - **car_ID**: Unique identifier for each car.
# - **symboling**: Risk factor rating assigned to the car (-3 to +3).
# - **CarName**: Name of the car.
# - **fueltype**: Type of fuel used by the car (e.g., gas, diesel).
# - **aspiration**: Type of aspiration used in the engine (e.g., std, turbo).
# - **doornumber**: Number of doors on the car (e.g., two, four).
# - **carbody**: Body style of the car (e.g., sedan, hatchback).
# - **drivewheel**: Type of drive wheel (e.g., fwd, rwd, 4wd).
# - **enginelocation**: Location of the engine (e.g., front, rear).
# - **wheelbase**: Distance between the front and rear wheels.
# - **enginesize**: Size of the engine in cubic inches.
# - **fuelsystem**: Type of fuel system (e.g., mpfi, 2bbl).
# - **boreratio**: Ratio of the bore (diameter of the cylinder) to the stroke.
# - **stroke**: Length of the piston stroke.
# - **compressionratio**: Ratio of the volume of the combustion chamber from its largest capacity to its smallest capacity.
# - **horsepower**: Power output of the engine.
# - **peakrpm**: Maximum revolutions per minute (RPM) of the engine.
# - **citympg**: Fuel efficiency in city driving (miles per gallon).
# - **highwaympg**: Fuel efficiency in highway driving (miles per gallon).
# - **price**: Price of the car.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                   count unique            top freq          mean          std  \
# car_ID            205.0    NaN            NaN  NaN         103.0    59.322565
# symboling         205.0    NaN            NaN  NaN      0.834146     1.245307
# CarName             205    147  toyota corona    6           NaN          NaN
# fueltype            205      2            gas  185           NaN          NaN
# aspiration          205      2            std  168           NaN          NaN
# doornumber          205      2           four  115           NaN          NaN
# carbody             205      5          sedan   96           NaN          NaN
# drivewheel          205      3            fwd  120           NaN          NaN
# enginelocation      205      2          front  202           NaN          NaN
# wheelbase         205.0    NaN            NaN  NaN     98.756585     6.021776
# carlength         205.0    NaN            NaN  NaN    174.049268    12.337289
# ...

# %%
df.describe(include='O')
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True), annot= True, fmt='.1f')
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True).price
# Out:
# car_ID             -0.109093
# symboling          -0.079978
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# carheight           0.119336
# curbweight          0.835305
# enginesize          0.874145
# boreratio           0.553173
# stroke              0.079443
# compressionratio    0.067984
# horsepower          0.808139
# peakrpm            -0.085267
# citympg            -0.685751
# highwaympg         -0.697599
# price               1.000000
# Name: price, dtype: float64

# %%
abs(df.corr(numeric_only=True).price).sort_values(ascending=False)
# Out:
# price               1.000000
# enginesize          0.874145
# curbweight          0.835305
# horsepower          0.808139
# carwidth            0.759325
# highwaympg          0.697599
# citympg             0.685751
# carlength           0.682920
# wheelbase           0.577816
# boreratio           0.553173
# carheight           0.119336
# car_ID              0.109093
# peakrpm             0.085267
# symboling           0.079978
# stroke              0.079443
# compressionratio    0.067984
# Name: price, dtype: float64

# %%
abs(df.corr(numeric_only=True).price).sort_values(ascending=False).head(8)
# Out:
# price         1.000000
# enginesize    0.874145
# curbweight    0.835305
# horsepower    0.808139
# carwidth      0.759325
# highwaympg    0.697599
# citympg       0.685751
# carlength     0.682920
# Name: price, dtype: float64

# %%
imp_features = abs(df.corr(numeric_only=True).price).sort_values(ascending=False).head(8).index.to_list()
imp_features
# Out:
# ['price',
#  'enginesize',
#  'curbweight',
#  'horsepower',
#  'carwidth',
#  'highwaympg',
#  'citympg',
#  'carlength']

# %%
imp_features.remove('price')
xy = imp_features + ['price']
sns.pairplot(df[xy])

# %% [markdown]
# # One Feature

# %%
X = df[['enginesize']]   
y = df[['price']]

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((164, 1), (41, 1))

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# array([-7613.37093949])

# %%
reg.coef_
# Out:
# array([[164.31545172]])

# %% [markdown]
# ## Evaluation

# %%
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([[ 7339.33516732],
#        [18841.41678794],
#        [14733.53049486],
#        [ 2409.87161562],
#        [10297.01329834],
#        [16376.68501209],
#        [ 7503.65061904],
#        [ 7503.65061904],
#        [22127.7258224 ],
#        [ 7503.65061904],
#        [19334.36314311],
#        [25742.66576031],
#        [ 3888.71068113],
#        [14404.89959141],
#        [ 7175.0197156 ],
#        [16376.68501209],
#        [14076.26868797],
#        [14733.53049486],
#        [10461.32875006],
#        [ 7503.65061904],
#        [10461.32875006],
#        [12104.48326729],
#        [14076.26868797],
#        [16376.68501209],
#        [20484.57130517],
#        [ 8325.22787766],
#        [ 8489.54332938],
#        [12104.48326729],
#        [ 8489.54332938],
#        [ 8325.22787766],
#        [10297.01329834],
#        [10297.01329834],
#        [17198.26227071],
#        [12433.11417074],
#        [ 8325.22787766],
#        [26728.55847065],
#        [10297.01329834],
# ...

# %%
from sklearn.metrics import mean_absolute_error, r2_score
print('Mean Absolute Error: ', mean_absolute_error(y_test, y_pred))
print('Accuracy: ', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  3195.0312395000433
# Accuracy:  0.7825324721447275

# %%
xy
# Out:
# ['enginesize',
#  'curbweight',
#  'horsepower',
#  'carwidth',
#  'highwaympg',
#  'citympg',
#  'carlength',
#  'price']

# %%
df.describe(include='O')
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
df.describe(include='O').columns.to_list()[1:]
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %% [markdown]
# # Multiple Features

# %%
cat = df.describe(include='O').columns.to_list()[1:]

# %%
for col in cat:
    print(df.groupby(col)['price'].mean())
    print()
# Out:
# fueltype
# diesel    15838.1500
# gas       12999.7982
# Name: price, dtype: float64
#
# aspiration
# std      12611.270833
# turbo    16298.166676
# Name: price, dtype: float64
#
# doornumber
# four    13501.152174
# two     12989.924078
# Name: price, dtype: float64
#
# carbody
# convertible    21890.500000
# hardtop        22208.500000
# hatchback      10376.652386
# sedan          14344.270833
# wagon          12371.960000
# Name: price, dtype: float64
#
# drivewheel
# 4wd    11087.463000
# fwd     9239.308333
# rwd    19910.809211
# Name: price, dtype: float64
#
# enginelocation
# front    12961.097361
# rear     34528.000000
# Name: price, dtype: float64
#
# enginetype
# dohc     18116.416667
# dohcv    31400.500000
# l        14627.583333
# ohc      11574.048426
# ohcf     13738.600000
# ohcv     25098.384615
# rotor    13020.000000
# Name: price, dtype: float64
#
# cylindernumber
# eight     37400.100000
# five      21630.469727
# four      10285.754717
# ...

# %%
cat
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
xy
# Out:
# ['enginesize',
#  'curbweight',
#  'horsepower',
#  'carwidth',
#  'highwaympg',
#  'citympg',
#  'carlength',
#  'price']

# %%
cols = xy + cat
cols.remove('price')
cols
# Out:
# ['enginesize',
#  'curbweight',
#  'horsepower',
#  'carwidth',
#  'highwaympg',
#  'citympg',
#  'carlength',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
X = df[cols]
X
# Out:
#      enginesize  curbweight  horsepower  carwidth  highwaympg  citympg  \
# 0           130        2548         111      64.1          27       21
# 1           130        2548         111      64.1          27       21
# 2           152        2823         154      65.5          26       19
# 3           109        2337         102      66.2          30       24
# 4           136        2824         115      66.4          22       18
# ..          ...         ...         ...       ...         ...      ...
# 200         141        2952         114      68.9          28       23
# 201         141        3049         160      68.8          25       19
# 202         173        3012         134      68.9          23       18
# 203         145        3217         106      68.9          27       26
# 204         141        3062         114      68.9          25       19
#
#      carlength fueltype aspiration doornumber      carbody drivewheel  \
# ...

# %%
y
# Out:
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 200  16845.0
# 201  19045.0
# 202  21485.0
# 203  22470.0
# 204  22625.0
#
# [205 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
#      enginesize  curbweight  horsepower  carwidth  highwaympg  citympg  \
# 4           136        2824         115      66.4          22       18
# 71          234        3740         155      71.7          18       16
# 134         121        2707         110      66.5          28       21
# 145         108        2510         111      65.4          29       24
# 122          98        2191          68      63.8          38       31
#
#      carlength fueltype aspiration doornumber    carbody drivewheel  \
# 4        176.6      gas        std       four      sedan        4wd
# 71       202.6      gas        std       four      sedan        rwd
# 134      186.6      gas        std        two  hatchback        fwd
# 145      172.0      gas      turbo       four      sedan        4wd
# 122      167.3      gas        std       four      sedan        fwd
#
#     enginelocation enginetype cylindernumber fuelsystem
# 4            front        ohc           five       mpfi
# ...

# %%
# X_train.to_csv('carpricetest.csv')

# %%
X_test.head()
# Out:
#      enginesize  curbweight  horsepower  carwidth  highwaympg  citympg  \
# 52           91        1905          68      64.2          38       31
# 181         161        3151         156      66.5          24       19
# 5           136        2507         110      66.3          25       19
# 18           61        1488          48      60.3          53       47
# 188         109        2300         100      65.5          32       26
#
#      carlength fueltype aspiration doornumber    carbody drivewheel  \
# 52       159.1      gas        std        two  hatchback        fwd
# 181      187.8      gas        std       four      wagon        rwd
# 5        177.3      gas        std        two      sedan        fwd
# 18       141.1      gas        std        two  hatchback        fwd
# 188      171.7      gas        std       four      sedan        fwd
#
#     enginelocation enginetype cylindernumber fuelsystem
# 52           front        ohc           four       2bbl
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(drop= 'first', sparse_output=False, handle_unknown='ignore').set_output(transform='pandas')
X_train_enc = ohe.fit_transform(X_train[cat])
X_test_enc = ohe.transform(X_test[cat])
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [6, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
X_train_enc
# Out:
#      fueltype_gas  aspiration_turbo  doornumber_two  carbody_hardtop  \
# 4             1.0               0.0             0.0              0.0
# 71            1.0               0.0             0.0              0.0
# 134           1.0               0.0             1.0              0.0
# 145           1.0               1.0             0.0              0.0
# 122           1.0               0.0             0.0              0.0
# ..            ...               ...             ...              ...
# 67            0.0               1.0             0.0              0.0
# 192           0.0               1.0             0.0              0.0
# 117           1.0               1.0             0.0              0.0
# 47            1.0               0.0             0.0              0.0
# 172           1.0               0.0             1.0              0.0
#
#      carbody_hatchback  carbody_sedan  carbody_wagon  drivewheel_fwd  \
# ...

# %%
X_train[imp_features]
# Out:
#      enginesize  curbweight  horsepower  carwidth  highwaympg  citympg  \
# 4           136        2824         115      66.4          22       18
# 71          234        3740         155      71.7          18       16
# 134         121        2707         110      66.5          28       21
# 145         108        2510         111      65.4          29       24
# 122          98        2191          68      63.8          38       31
# ..          ...         ...         ...       ...         ...      ...
# 67          183        3515         123      70.3          25       22
# 192          97        2579          68      66.9          38       33
# 117         134        3130         142      68.3          24       18
# 47          258        4066         176      69.6          19       15
# 172         146        2975         116      65.6          30       24
#
#      carlength
# 4        176.6
# 71       202.6
# 134      186.6
# 145      172.0
# 122      167.3
# ..         ...
# ...

# %%
# Scaling for numerical
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler().set_output(transform='pandas')
X_train_num = scaler.fit_transform(X_train[imp_features])
X_test_num = scaler.transform(X_test[imp_features])

# %%
X_train_num
# Out:
#      enginesize  curbweight  horsepower  carwidth  highwaympg   citympg  \
# 4      0.257812    0.472163    0.300000  0.464646    0.157895  0.138889
# 71     0.640625    0.861453    0.490476  1.000000    0.052632  0.083333
# 134    0.199219    0.422439    0.276190  0.474747    0.315789  0.222222
# 145    0.148438    0.338717    0.280952  0.363636    0.342105  0.305556
# 122    0.109375    0.203145    0.076190  0.202020    0.578947  0.500000
# ..          ...         ...         ...       ...         ...       ...
# 67     0.441406    0.765831    0.338095  0.858586    0.236842  0.250000
# 192    0.105469    0.368041    0.076190  0.515152    0.578947  0.555556
# 117    0.250000    0.602210    0.428571  0.656566    0.210526  0.138889
# 47     0.734375    1.000000    0.590476  0.787879    0.078947  0.055556
# 172    0.296875    0.536337    0.304762  0.383838    0.368421  0.305556
#
#      carlength
# 4     0.503937
# 71    0.913386
# 134   0.661417
# 145   0.431496
# 122   0.357480
# ...

# %%
X_train_num.min(), X_train_num.max()
# Out:
# (enginesize    0.0
#  curbweight    0.0
#  horsepower    0.0
#  carwidth      0.0
#  highwaympg    0.0
#  citympg       0.0
#  carlength     0.0
#  dtype: float64,
#  enginesize    1.0
#  curbweight    1.0
#  horsepower    1.0
#  carwidth      1.0
#  highwaympg    1.0
#  citympg       1.0
#  carlength     1.0
#  dtype: float64)

# %%
X_train_all = pd.concat([X_train_num, X_train_enc], axis=1)
X_train_all
# Out:
#      enginesize  curbweight  horsepower  carwidth  highwaympg   citympg  \
# 4      0.257812    0.472163    0.300000  0.464646    0.157895  0.138889
# 71     0.640625    0.861453    0.490476  1.000000    0.052632  0.083333
# 134    0.199219    0.422439    0.276190  0.474747    0.315789  0.222222
# 145    0.148438    0.338717    0.280952  0.363636    0.342105  0.305556
# 122    0.109375    0.203145    0.076190  0.202020    0.578947  0.500000
# ..          ...         ...         ...       ...         ...       ...
# 67     0.441406    0.765831    0.338095  0.858586    0.236842  0.250000
# 192    0.105469    0.368041    0.076190  0.515152    0.578947  0.555556
# 117    0.250000    0.602210    0.428571  0.656566    0.210526  0.138889
# 47     0.734375    1.000000    0.590476  0.787879    0.078947  0.055556
# 172    0.296875    0.536337    0.304762  0.383838    0.368421  0.305556
#
#      carlength  fueltype_gas  aspiration_turbo  doornumber_two  ...  \
# ...

# %%
X_test_all = pd.concat([X_test_num, X_test_enc], axis=1)
X_test_all.head()
# Out:
#      enginesize  curbweight  horsepower  carwidth  highwaympg   citympg  \
# 52     0.082031    0.081598    0.076190  0.242424    0.578947  0.500000
# 181    0.355469    0.611135    0.495238  0.474747    0.210526  0.166667
# 5      0.257812    0.337442    0.276190  0.454545    0.236842  0.166667
# 18    -0.035156   -0.095623   -0.019048 -0.151515    0.973684  0.944444
# 188    0.152344    0.249469    0.228571  0.373737    0.421053  0.361111
#
#      carlength  fueltype_gas  aspiration_turbo  doornumber_two  ...  \
# 52    0.228346           1.0               0.0             1.0  ...
# 181   0.680315           1.0               0.0             0.0  ...
# 5     0.514961           1.0               0.0             1.0  ...
# 18   -0.055118           1.0               0.0             1.0  ...
# 188   0.426772           1.0               0.0             0.0  ...
#
#      cylindernumber_six  cylindernumber_twelve  cylindernumber_two  \
# ...

# %%
reg2 = LinearRegression()
reg2.fit(X_train_all, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg2.predict(X_test_all)

print('Mean Absolute Error: ', mean_absolute_error(y_test, y_pred))
print('Accuracy: ', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  2728.040187557858
# Accuracy:  0.8053246303962601

# %%
y_pred[:5]
# Out:
# array([[ 5853.83769101],
#        [21281.5734675 ],
#        [16238.54434348],
#        [11582.58214596],
#        [10466.74456702]])

# %%
reg2.intercept_
# Out:
# array([18382.23338597])

# %%
reg2.coef_
# Out:
# array([[ 10845.85474969,  10604.8489965 ,   2299.76067431,
#           6213.13825227,   5136.17650868,  -5823.3074453 ,
#          -2471.50198097,    468.52323755,   1456.26895689,
#            125.57502774,  -3947.08821092,  -2458.99997958,
#          -1503.56527772,  -2488.27893912,    714.33727324,
#           2534.9868588 ,  11351.70521985,  -1944.19731637,
#           1701.1412796 ,   1416.88289199,  -5542.33723515,
#          -4925.19567516, -12061.62831042, -15051.21908468,
#         -10074.89786357,  -5122.53654432,  -4925.19567516,
#           -961.78514154,  -1807.96382401,   -468.52323755,
#          -3806.23784072,   -395.29717733,  -3199.1996618 ,
#          -2769.72432343]])

# %% [markdown]
# # Test prediction

# %%
X_new = X_test.iloc[10,:]
X_new.to_frame().T
# Out:
#    enginesize curbweight horsepower carwidth highwaympg citympg carlength  \
# 12        164       2710        121     64.8         28      21     176.8
#
#    fueltype aspiration doornumber carbody drivewheel enginelocation  \
# 12      gas        std        two   sedan        rwd          front
#
#    enginetype cylindernumber fuelsystem
# 12        ohc            six       mpfi

# %%
def process_new_data(X_new):
    X_new = X_new.to_frame().T
    X_new_num = scaler.transform(X_new[imp_features])
    X_new_enc = ohe.transform(X_new[cat])
    X_new_all = pd.concat([X_new_num, X_new_enc], axis=1)
    return X_new_all

X_new_all = process_new_data(X_new)
X_new_all
# Out:
#     enginesize  curbweight  horsepower  carwidth  highwaympg   citympg  \
# 12    0.367188    0.423714    0.328571   0.30303    0.315789  0.222222
#
#     carlength  fueltype_gas  aspiration_turbo  doornumber_two  ...  \
# 12   0.507087           1.0               0.0             1.0  ...
#
#     cylindernumber_six  cylindernumber_twelve  cylindernumber_two  \
# 12                 1.0                    0.0                 0.0
#
#     fuelsystem_2bbl  fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mfi  \
# 12              0.0              0.0             0.0             0.0
#
#     fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi
# 12              1.0              0.0              0.0
#
# [1 rows x 34 columns]

# %%
reg2.predict(X_new_all)
# Out:
# array([[21427.61046857]])

# %%
y_test.iloc[10,:]
# Out:
# price    20970.0
# Name: 12, dtype: float64

# %%
def process_new_data(X_test):
    # Ensure X_test is a DataFrame
    if not isinstance(X_test, pd.DataFrame):
        X_test = X_test.to_frame().T
    
    # Process numerical features
    X_test_num = scaler.transform(X_test[imp_features])
    
    # Process categorical features
    X_test_enc = ohe.transform(X_test[cat])
    
    # Concatenate numerical and categorical features
    X_test_all = pd.concat([X_test_num, X_test_enc], axis=1)
    
    return X_test_all

# %%
X_test_new = process_new_data(X_test)
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [6, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
X_test_new.head()
# Out:
#      enginesize  curbweight  horsepower  carwidth  highwaympg   citympg  \
# 52     0.082031    0.081598    0.076190  0.242424    0.578947  0.500000
# 181    0.355469    0.611135    0.495238  0.474747    0.210526  0.166667
# 5      0.257812    0.337442    0.276190  0.454545    0.236842  0.166667
# 18    -0.035156   -0.095623   -0.019048 -0.151515    0.973684  0.944444
# 188    0.152344    0.249469    0.228571  0.373737    0.421053  0.361111
#
#      carlength  fueltype_gas  aspiration_turbo  doornumber_two  ...  \
# 52    0.228346           1.0               0.0             1.0  ...
# 181   0.680315           1.0               0.0             0.0  ...
# 5     0.514961           1.0               0.0             1.0  ...
# 18   -0.055118           1.0               0.0             1.0  ...
# 188   0.426772           1.0               0.0             0.0  ...
#
#      cylindernumber_six  cylindernumber_twelve  cylindernumber_two  \
# ...

# %%
# X_test_new_single = X_test_new.iloc[10,:].to_frame().T
# X_test_new_single

# %%
# Predict the values using the trained model
y_pred = reg2.predict(X_test_new)

# Create a DataFrame with real and predicted values
comparison_df = pd.DataFrame({
    'Real': y_test.values.flatten(),
    'Predicted': y_pred.flatten()
})

# Display the DataFrame
comparison_df.head()
# Out:
#       Real     Predicted
# 0   6795.0   5853.837691
# 1  15750.0  21281.573467
# 2  15250.0  16238.544343
# 3   5151.0  11582.582146
# 4   9995.0  10466.744567

# %%
comparison_df.plot()
# Out:
# <Axes: >

# %%
import pickle

# %%
# Save the model to a .pkl file
with open('car_price_model.pkl', 'wb') as file:
    pickle.dump(reg2, file)

# %%
# from sklearn.preprocessing import OneHotEncoder

# ohe = OneHotEncoder(drop= 'first', sparse_output=False, handle_unknown='ignore').set_output(transform='pandas')
# X_train_enc = ohe.fit_transform(X_train[cat])
# X_test_enc = ohe.transform(X_test[cat])

# %%
# # Scaling for numerical
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler().set_output(transform='pandas')
# X_train_num = scaler.fit_transform(X_train[imp_features])
# X_test_num = scaler.transform(X_test[imp_features])

# %%
# Initialize and fit the preprocessors
scaler = MinMaxScaler().set_output(transform='pandas')
scaler.fit(X_train[imp_features])

ohe = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore').set_output(transform='pandas')
ohe.fit(X_train[cat])

# Save the fitted preprocessors
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

with open('ohe.pkl', 'wb') as f:
    pickle.dump(ohe, f)

# %%
import pickle

# After fitting your preprocessors
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

with open('ohe.pkl', 'wb') as f:
    pickle.dump(ohe, f)

# %%
with open('car_price_model.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
X_new = X_test.iloc[10,:]
X_new.to_frame().T
# Out:
#    enginesize curbweight horsepower carwidth highwaympg citympg carlength  \
# 12        164       2710        121     64.8         28      21     176.8
#
#    fueltype aspiration doornumber carbody drivewheel enginelocation  \
# 12      gas        std        two   sedan        rwd          front
#
#    enginetype cylindernumber fuelsystem
# 12        ohc            six       mpfi

# %%
def process_new_data(X_new):
    X_new = X_new.to_frame().T
    X_new_num = scaler.transform(X_new[imp_features])
    X_new_enc = ohe.transform(X_new[cat])
    X_new_all = pd.concat([X_new_num, X_new_enc], axis=1)
    return X_new_all

X_new_all = process_new_data(X_new)
X_new_all
# Out:
#     enginesize  curbweight  horsepower  carwidth  highwaympg   citympg  \
# 12    0.367188    0.423714    0.328571   0.30303    0.315789  0.222222
#
#     carlength  fueltype_gas  aspiration_turbo  doornumber_two  ...  \
# 12   0.507087           1.0               0.0             1.0  ...
#
#     cylindernumber_six  cylindernumber_twelve  cylindernumber_two  \
# 12                 1.0                    0.0                 0.0
#
#     fuelsystem_2bbl  fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mfi  \
# 12              0.0              0.0             0.0             0.0
#
#     fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi
# 12              1.0              0.0              0.0
#
# [1 rows x 34 columns]

# %%
cylindernumber_three = 'cylindernumber_three'
# cylindernumber_three = 'enginetype_dohcv'

cylindernumber_three in X_new_all.columns
# Out:
# False

# %%
model.predict(X_new_all)
# Out:
# array([[21427.61046857]])

# %%
y_test.iloc[10,:]
# Out:
# price    20970.0
# Name: 12, dtype: float64
