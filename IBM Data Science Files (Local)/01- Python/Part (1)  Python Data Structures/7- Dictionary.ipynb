# %% [markdown]
# ## (7) Dictionaries

# %% [markdown]
# > We've been learning about *sequences* in Python but now we're going to switch gears and learn about *mappings* in Python. If you're familiar with other languages you can think of these Dictionaries as hash tables.
#
# * So what are mappings? Mappings are a collection of objects that are stored by a *key*, unlike a sequence that stored objects by their relative position. This is an important distinction, since mappings won't retain order since they have objects defined by a key.
# * Each element in a dictionary stores a pair of data and represented by a __*key:value*__ pair.

# %%
# Construct a dictionary
ages = {"Muhammad": 24, "Maryam": 42, "Anas": 58}
print(ages["Anas"])
print(ages["Maryam"])
# Out:
# 58
# 42

# %%
ages.keys()    # Custom index by label
# Out:
# dict_keys(['Muhammad', 'Maryam', 'Anas'])

# %%
 l = list(ages.keys())
l
# Out:
# ['Muhammad', 'Maryam', 'Anas']

# %%
l[0]
# Out:
# 'Muhammad'

# %%
ages.values()
# Out:
# dict_values([24, 42, 58])

# %%
list(ages.values())
# Out:
# [24, 42, 58]

# %%
ages.items()
# Out:
# dict_items([('Muhammad', 24), ('Maryam', 42), ('Anas', 58)])

# %%
list(ages.items())
# Out:
# [('Muhammad', 24), ('Maryam', 42), ('Anas', 58)]

# %%
ages += {'Ahmad': 31}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ages += {'Ahmad': 31}
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'dict'

# %%
ages['Ahmad'] = 31   # Adding New Element

# %%
ages
# Out:
# {'Muhammad': 24, 'Maryam': 42, 'Anas': 58, 'Ahmad': 31}

# %%
ages.update({"Ali": 42})

# %%
ages.update({"Ali": 30, "Anas": 31})

# %%
ages
# Out:
# {'Muhammad': 24, 'Maryam': 42, 'Anas': 31, 'Ahmad': 31, 'Ali': 30}

# %%
ages['Maryam'] = 25

# %%
ages
# Out:
# {'Muhammad': 24, 'Maryam': 25, 'Anas': 31, 'Ahmad': 31, 'Ali': 30}

# %%
ages[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 ages[1]
#
# KeyError: 1

# %%
ages[1] = 33   # bad naming for key

# %%
ages[1]
# Out:
# 33

# %%
ages['Maryam']
# Out:
# 42

# %%
mydict={}
mydict['Fruits']= ['Apple', 'Orange', 'Banana']
mydict['Vegetables']= ('Tomato','Beans')
mydict
# Out:
# {'Fruits': ['Apple', 'Orange', 'Banana'], 'Vegetables': ('Tomato', 'Beans')}

# %%
bad_dict = {2: "one two three"}

# %%
# What is the result of this code?
primes = {1: 2, 2: 3, 4: 7, 7:17}
print(primes[primes[4]])
# Out:
# 17

# %%
# To determine whether a key is in a dictionary, you can use (in) and (not in), as you can use them for a list.
ages
# Out:
# {'Muhammad': 24, 'Maryam': 42, 'Anas': 58, 'Ahmad': 31}

# %%
'Ahmad' in ages   # Lookup for a key
# Out:
# True

# %%
my_dict = {'name': 'Ali', 'age': 30, 'power': False}
my_dict['power']
# Out:
# False

# %%
my_dict.get('name')     # my_dict['name']
# Out:
# 'Ali'

# %%
my_dict['last_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 my_dict['last_name']
#
# KeyError: 'last_name'

# %%
my_dict.get('last_name')

# %%
my_dict.get('last_name', 'Not Found')
# Out:
# 'Not Found'

# %%
del my_dict['name']
my_dict
# Out:
# {'age': 30, 'power': False}

# %%
my_dict.pop('name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 my_dict.pop('name')
#
# KeyError: 'name'

# %%
my_dict.pop('name', None)

# %%
my_dict.pop('name', 'key Not Found')
# Out:
# 'key Not Found'

# %%
my_dict.pop('age', None)
my_dict
# Out:
# {'power': False}

# %%
my_dict.pop('number', None)

# %%
my_dict.pop('number', 'Not Found')
# Out:
# 'Not Found'

# %%
my_dict
# Out:
# {'power': False}

# %%
my_dict.clear()
my_dict
# Out:
# {}
