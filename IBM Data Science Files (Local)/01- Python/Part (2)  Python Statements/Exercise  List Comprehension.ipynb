# %% [markdown]
# # Exercise
# **Using List Comprehension: : Return a list of words that starts with "a"**
#
#
# ```
# Input : "I am Ali. I agree with you. Your aid is appreciated"
# Output: ['am', 'agree', 'aid', 'appreciated']
# ```

# %%
# Try Here
s = "I am Ali. I agree with you. Your aid is appreciated"

# %%
word1 = 'Ali'
word2 = 'heba'

word1[0].lower() == 'a'
# Out:
# True

# %%
word1.lower().startswith('a')
# Out:
# True

# %%
s = "I am Ali. I agree with you. Your aid is appreciated"

s.split()
# Out:
# ['I',
#  'am',
#  'Ali.',
#  'I',
#  'agree',
#  'with',
#  'you.',
#  'Your',
#  'aid',
#  'is',
#  'appreciated']

# %%
l = []
for word in s.split():
    if word[0].lower() == 'a':
        l.append(word)
l
# Out:
# ['am', 'Ali.', 'agree', 'aid', 'appreciated']

# %%
[word for word in s.split() if word[0].lower()== 'a' ]
# Out:
# ['am', 'Ali.', 'agree', 'aid', 'appreciated']

# %%
[word for word in s.split() if word.lower().startswith ('a') ]
# Out:
# ['am', 'Ali.', 'agree', 'aid', 'appreciated']

# %% [markdown]
# # Solution

# %%
s= "I am Ali. I agree with you. Your aid is appreciated"
[word for word in s.split() if word.startswith("a") ]
# Out:
# ['am', 'agree', 'aid', 'appreciated']

# %% [markdown]
# # Another Solution

# %%
s= "I am Ali. I agree with you. Your aid is appreciated"
[word for word in s.split() if word[0]== "a" ]
# Out:
# ['am', 'agree', 'aid', 'appreciated']

# %%
s= "I am Ali. I agree with you. Your aid is appreciated"
s.split()
# Out:
# ['I',
#  'am',
#  'Ali.',
#  'I',
#  'agree',
#  'with',
#  'you.',
#  'Your',
#  'aid',
#  'is',
#  'appreciated']

# %%
x =5

if x == 5:
    print("x is 5")
print('Hello')
