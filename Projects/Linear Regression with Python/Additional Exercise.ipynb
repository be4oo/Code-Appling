# %%
# %%time
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from linreg import LinearModel
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
#Explicitly specified the xlrd engine
df = pd.read_excel('chirps.xls', engine='xlrd')
df.head()
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#            X          Y
# 0  20.000000  88.599998
# 1  16.000000  71.599998
# 2  19.799999  93.300003
# 3  18.400000  84.300003
# 4  17.100000  80.599998

# %%
df.shape
# Out:
# (15, 2)

# %%
x = df.X.values
y = df.Y.values
y
# Out:
# array([88.59999847, 71.59999847, 93.30000305, 84.30000305, 80.59999847,
#        75.19999695, 69.69999695, 82.        , 69.40000153, 83.30000305,
#        79.59999847, 82.59999847, 80.59999847, 83.5       , 76.30000305])

# %%
x = np.reshape(x, (x.shape[0], 1))
y = np.reshape(y, (y.shape[0], 1))
y
# Out:
# array([[88.59999847],
#        [71.59999847],
#        [93.30000305],
#        [84.30000305],
#        [80.59999847],
#        [75.19999695],
#        [69.69999695],
#        [82.        ],
#        [69.40000153],
#        [83.30000305],
#        [79.59999847],
#        [82.59999847],
#        [80.59999847],
#        [83.5       ],
#        [76.30000305]])

# %%
model = LinearModel(1)

losses = model.train(
    x, y,
    200, 0.0001
)
# Out:
# Iter: 0, Current loss: 3384.2033
# Iter: 20, Current loss: 1088.3510
# Iter: 40, Current loss: 354.2467
# Iter: 60, Current loss: 119.5151
# Iter: 80, Current loss: 44.4590
# Iter: 100, Current loss: 20.4596
# Iter: 120, Current loss: 12.7856
# Iter: 140, Current loss: 10.3318
# Iter: 160, Current loss: 9.5471
# Iter: 180, Current loss: 9.2961

# %%
plt.plot(losses);

# %%
y_preds = model.forward_pass(x)

# %%
plt.plot(y, y_preds, 'r.');

# %%
print(model.W, model.b)
# Out:
# [[4.7137345]] 1.0345114924702443
