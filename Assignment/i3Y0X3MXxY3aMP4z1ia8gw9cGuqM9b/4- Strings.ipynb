# %% [markdown]
# ### Non-Scalar Objects ( compound data types )
# * strings
# * lists
# * tuples
# * dictionaries
# * set

# %% [markdown]
# ## (4) Strings

# %% [markdown]
# >* If you want to use text in Python, you have to use a string.
# * A __string__ is created by entering text between two single or double quotation marks.

# %%
var = 's'
var2 = 'u'
var3 = ' '
var4 = '#'

# %%
'Python'
# Out:
# 'Python'

# %%
"Python is fun!"
# Out:
# 'Python is fun!'

# %%
print("I don't like Music")
# Out:
# I don't like Music

# %%
# print('I don't like Music')

# %%
print('she said: "Yes"')
# Out:
# she said: "Yes"

# %%
# print("she said: "Yes"")

# %%
print('she said: "I don\'t like Music"')
# Out:
# she said: "I don't like Music"

# %%
print("she said: \"I don't like Music\"")
# Out:
# she said: "I don't like Music"

# %%
' I don\'t like Music '
# Out:
# " I don't like Music "

# %%
" she said: \"Yes\" "  # \ is escape
# Out:
# ' she said: "Yes" '

# %%
review = '''I bought this product.
I really like it. 
I will buy it again. '''
print(review)
# Out:
# I bought this product.
# I really like it.
# I will buy it again.

# %% [markdown]
# ### String Output

# %%
print(" Hi, there! \n My name is Ahmad")     # \n represents a new line
# Out:
#  Hi, there!
#  My name is Ahmad

# %%
a = 1+1
print(a)
# Out:
# 2

# %%
a
# Out:
# 2

# %%
type(a)
# Out:
# int

# %% [markdown]
# ### String Input

# %%
input("Enter something please: ")
# Out:
# '0'

# %%
message= input("Enter a number please: ")

# %%
message
# Out:
# '0'

# %%
type(message)
# Out:
# str

# %% [markdown]
# ### Casting your input

# %%
my_num= int(input("Enter a number please: "))

# %%
type(my_num)
# Out:
# int

# %%
my_num2= float(input("Enter a number please: "))

# %%
type(my_num2)
# Out:
# float

# %%
my_num3= float(input("Enter a number please: "))

# %%
my_num3
# Out:
# 0.0

# %% [markdown]
# ### String Concatenation

# %%
"Hi" + 'friends'
# Out:
# 'Hifriends'

# %%
"Hi" + ' friends'
# Out:
# 'Hi friends'

# %%
"Hi" + ', ' + 'friends'
# Out:
# 'Hi, friends'

# %%
s1= 'Hi'
s2 = 'friends'
print(s1 + ", " + s2)
# Out:
# Hi, friends

# %%
print("2" + "2")
# Out:
# 22

# %%
1 + '2' + 3 + '4'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 1 + '2' + 3 + '4'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### String Multiplication !

# %%
print("Python" * 3)
# Out:
# PythonPythonPython

# %%
print(s1 * 3)
# Out:
# HiHiHi

# %%
print((s1 + ' ') * 3)
# Out:
# Hi Hi Hi

# %%
4 * '2'
# Out:
# '2222'

# %%
'17' * '87'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 '17' * '87'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
'pythonisfun' * 4.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 'pythonisfun' * 4.0
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
s = 'python or java'
s2 = 'java or python'

# %% [markdown]
# ### String Indexing
# >* A string is a __sequence__ of characters
# *  we can use indexes to call parts of this sequence
# * square brackets \[ \] used to perform indexing into a string to get the value at a certain index/position

# %%
s= 'I am different'
#   0123
#           -3-2-1

# %%
s[1]   # first position ?
# Out:
# ' '

# %%
s[5]
# Out:
# 'd'

# %%
s[-1]
# Out:
# 't'

# %% [markdown]
#  ### String Slicing
# >* can slices trings using [start:stop:step]
# * if give two numbers, [start:stop], step = 1 by default
# * if no start, start = 0 by default
# * if no stop, stop = len(s) by default

# %%
s[0:3]
# Out:
# 'I a'

# %%
s[:3]
# Out:
# 'I a'

# %%
s[5:]
# Out:
# 'different'

# %%
s[0:8:2]
# Out:
# 'Ia i'

# %%
s[:]
# Out:
# 'I am different'

# %%
s[::]
# Out:
# 'I am different'

# %%
s[::-1] # Mirror
# Out:
# 'tnereffid ma I'

# %%
s[9:1:-2]
# Out:
# 'efdm'

# %%
s[:6]
# Out:
# 'I am d'

# %%
s[2:]
# Out:
# 'am different'

# %%
s[:]
# Out:
# 'I am different'

# %%
s
# Out:
# 'I am different'

# %%
s[:4] = 'We are'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 s[:4] = 'We are'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# > **Note**: Strings are "immmutable"   : can not be modified

# %%
s = "hello"

# %%
s[0] = 'y'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 s[0] = 'y'
#
# TypeError: 'str' object does not support item assignment

# %%
s[1:]
# Out:
# 'ello'

# %%
s = 'y' + s[1:]

# %%
s
# Out:
# 'yello'

# %% [markdown]
# ### Basic Built-in String methods
# * Objects in Python usually have built-in methods that can perform actions or commands on the object itself.
# * __object.method(parameters)__

# %%
s2 = s.upper()
s2
# Out:
# 'YELLO'

# %%
s.upper()
# Out:
# 'YELLO'

# %%
s
# Out:
# 'yello'

# %%
s2
# Out:
# 'YELLO'

# %%
s2.lower()
# Out:
# 'yello'

# %%
s2
# Out:
# 'YELLO'

# %%
s = 'i am learning python'
s.capitalize()
# Out:
# 'I am learning python'

# %%
s = '  Hello, I_am learning_Python'
s.split('_')
# Out:
# ['  Hello, I', 'am learning', 'Python']

# %%
s.split()
# Out:
# ['Hello,', 'I_am', 'learning_Python']

# %%
s.split(' ')
# Out:
# ['', '', 'Hello,', 'I_am', 'learning_Python']

# %%
s.split('  ')
# Out:
# ['', 'Hello, I_am learning_Python']

# %%
s.split('m')
# Out:
# ['  Hello, I_a', ' learning_Python']

# %%
s.split('f')
# Out:
# ['  Hello, I_am learning_Python']

# %%
'A_B_C'.split(sep='_')
# Out:
# ['A', 'B', 'C']

# %%
s.replace('Python', 'Java')
# Out:
# '  Hello, I_am learning_Java'

# %%
s.replace('python', 'Java')
# Out:
# '  Hello, I_am learning_Python'

# %%
s
# Out:
# '  Hello, I_am learning_Python'

# %%
s2 = s.replace('Python', 'Java')

# %%
s2
# Out:
# ' Hello, I_am learning_Java'

# %%
s
# Out:
# '  Hello, I_am learning_Python'

# %%
s2
# Out:
# '  Hello, I_am learning_Java'

# %%
s.find('Java')
# Out:
# -1

# %%
s2.find('Java')
# Out:
# 23

# %%
s2[23:]
# Out:
# 'Java'

# %%
s.find('Python')
# Out:
# 23

# %%
s
# Out:
# '  Hello, I_am learning_Python'

# %%
s.find('o')
# Out:
# 6

# %%
s.find('o', 10)
# Out:
# 27

# %%
s.find('o', 2)
# Out:
# 6

# %%
first_occurance = s.find('o')
print(first_occurance)
# Out:
# 6

# %%
second_occurance = s.find('o', first_occurance+1)
print(second_occurance)
# Out:
# 27

# %%
len(s)
# Out:
# 29

# %%
len(s[first_occurance+1:])
# Out:
# 22

# %%
s[first_occurance+1:].find('o')
# Out:
# 20

# %%
third_occurance = s.find('o', second_occurance+1)
print(third_occurance)
# Out:
# -1

# %%
s.find('o')
# Out:
# 6

# %%
s.index('o')
# Out:
# 6

# %%
s.find('f')
# Out:
# -1

# %%
s.index('f')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 s.index('f')
#
# ValueError: substring not found

# %% [markdown]
# ### Print Formatting

# %%
# Replace curly brakets {} with values
' I say {} to {} {} times'.format('hi', 'Osama', 3)
# Out:
# ' I say hi to Osama 3 times'

# %%
# Another method
"I say %s to %s %d times." %('hi','Osama',3)
# Out:
# 'I say hi to Osama 3 times.'

# %%
gpa= 3.75
"I got %f in math" %(gpa)
# Out:
# 'I got 3.750000 in math'

# %%
"I got %0.1f in math" %(gpa)
# Out:
# 'I got 3.8 in math'

# %%
gpa
# Out:
# 3.75

# %%
name = 'Ahmad'
age = 30

# %%
print('My name is', name, '\nand my age is', age)
# Out:
# My name is Ahmad
# and my age is 30

# %%
print('My name is {} and my age is {}'.format(name, age))
# Out:
# My name is Ahmad and my age is 30

# %%
print(f'My name is {name} and my age is {age}')
# Out:
# My name is Ahmad and my age is 30

# %%
print('My name is {1} and my age is {0}'.format(name, age))
# Out:
# My name is 30 and my age is Ahmad

# %% [markdown]
# ### Escape Sequences

# %%
# New line escape sequence

print(" Python \n is the best" )
# Out:
#  Python
#  is the best

# %%
# Tab escape sequence

print(" Python \t is the best" )
# Out:
#  Python 	 is the best

# %%
# Include back slash in string

print(" Python \ is the best" )
# Out:
#  Python \ is the best

# %%
# r will tell python that string will be display as raw string

print(r" Python \ is the best" )
# Out:
#  Python \ is the best

# %%
print('Anaconda Path: C:\\ProgramData\\Anaconda3')
# Out:
# Anaconda Path: C:\ProgramData\Anaconda3

# %%
print(r'Anaconda Path: C:\ProgramData\table')
# Out:
# Anaconda Path: C:\ProgramData\table

# %%
print('Anaconda Path: C:\ProgramData\table')
# Out:
# Anaconda Path: C:\ProgramData	able

# %%
print('Anaconda Path: C:\ProgramData\\table')
# Out:
# Anaconda Path: C:\ProgramData\table
